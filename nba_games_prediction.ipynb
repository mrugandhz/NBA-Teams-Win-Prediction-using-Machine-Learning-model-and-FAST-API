# %% [markdown]
# # Collect data

# %%
#%pip install nba_api

# %%
from nba_api.stats.endpoints import leaguegamefinder
gamefinder = leaguegamefinder.LeagueGameFinder(date_from_nullable='01/31/2020', league_id_nullable='00')
games = gamefinder.get_data_frames()[0]
games.head()
# Out:
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION           TEAM_NAME     GAME_ID  \
# 0     42022  1610612751               BKN       Brooklyn Nets  0042200124
# 1     42022  1610612755               PHI  Philadelphia 76ers  0042200124
# 2     42022  1610612752               NYK     New York Knicks  0042200133
# 3     42022  1610612737               ATL       Atlanta Hawks  0042200113
# 4     42022  1610612738               BOS      Boston Celtics  0042200113
#
#     GAME_DATE      MATCHUP    WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  \
# 0  2023-04-22  BKN vs. PHI  None  229   76  ...   0.688     5    32   37   18
# 1  2023-04-22    PHI @ BKN  None  215   85  ...   0.917    14    35   49   16
# 2  2023-04-21  NYK vs. CLE     W  241   99  ...   0.611    11    34   45   21
# 3  2023-04-21  ATL vs. BOS     W  240  130  ...   0.813    11    37   48   24
# 4  2023-04-21    BOS @ ATL     L  240  122  ...   0.688     6    23   29   31
#
#    STL  BLK  TOV  PF  PLUS_MINUS
# 0    2    6   10  12        -7.4
# 1    7    3    7  17         8.0
# 2   14    5   14  17        20.0
# 3    5    6   18  15         8.0
# 4   11    0   12  17        -8.0
#
# [5 rows x 28 columns]

# %% [markdown]
# # Clean and Explore data

# %%
games.columns
# Out:
# Index(['SEASON_ID', 'TEAM_ID', 'TEAM_ABBREVIATION', 'TEAM_NAME', 'GAME_ID',
#        'GAME_DATE', 'MATCHUP', 'WL', 'MIN', 'PTS', 'FGM', 'FGA', 'FG_PCT',
#        'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB',
#        'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PLUS_MINUS'],
#       dtype='object')

# %%
games = games[['TEAM_NAME', 'GAME_ID', 'GAME_DATE', 'MATCHUP', 'WL', 'PLUS_MINUS']]

# %%
games
# Out:
#                TEAM_NAME     GAME_ID   GAME_DATE      MATCHUP    WL  \
# 0          Brooklyn Nets  0042200124  2023-04-22  BKN vs. PHI  None
# 1     Philadelphia 76ers  0042200124  2023-04-22    PHI @ BKN  None
# 2        New York Knicks  0042200133  2023-04-21  NYK vs. CLE     W
# 3          Atlanta Hawks  0042200113  2023-04-21  ATL vs. BOS     W
# 4         Boston Celtics  0042200113  2023-04-21    BOS @ ATL     L
# ...                  ...         ...         ...          ...   ...
# 8815        Phoenix Suns  0021900725  2020-01-31  PHX vs. OKC     L
# 8816    Dallas Mavericks  0021900722  2020-01-31    DAL @ HOU     L
# 8817       Brooklyn Nets  0021900721  2020-01-31  BKN vs. CHI     W
# 8818     Toronto Raptors  0021900720  2020-01-31    TOR @ DET     W
# 8819     Detroit Pistons  0021900720  2020-01-31  DET vs. TOR     L
#
#       PLUS_MINUS
# 0           -7.4
# 1            8.0
# 2           20.0
# 3            8.0
# 4           -8.0
# ...          ...
# 8815        -4.0
# 8816        -7.0
# 8817        15.0
# 8818        13.0
# 8819       -13.0
#
# [8820 rows x 6 columns]

# %% [markdown]
# final DataFrame: two columns: 1.result of game: target 2.score statistics comparing two teams: feature

# %%
import pandas as pd # For Data Pre-processing

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8820 entries, 0 to 8819
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   TEAM_NAME   8820 non-null   object
#  1   GAME_ID     8820 non-null   object
#  2   GAME_DATE   8820 non-null   object
#  3   MATCHUP     8820 non-null   object
#  4   WL          8818 non-null   object
#  5   PLUS_MINUS  8820 non-null   float64
# dtypes: float64(1), object(5)
# memory usage: 413.6+ KB

# %%
games['GAME_DATE'] = pd.to_datetime(games['GAME_DATE']) # Normalizing the Date

# %%
games['GAME_DATE']
# Out:
# 0      2023-04-22
# 1      2023-04-22
# 2      2023-04-21
# 3      2023-04-21
# 4      2023-04-21
#           ...
# 8815   2020-01-31
# 8816   2020-01-31
# 8817   2020-01-31
# 8818   2020-01-31
# 8819   2020-01-31
# Name: GAME_DATE, Length: 8820, dtype: datetime64[ns]

# %%
games = games.sort_values('GAME_DATE')
games
# Out:
#                    TEAM_NAME     GAME_ID  GAME_DATE      MATCHUP    WL  \
# 8819         Detroit Pistons  0021900720 2020-01-31  DET vs. TOR     L
# 8806      Los Angeles Lakers  0021900726 2020-01-31  LAL vs. POR     L
# 8807   Oklahoma City Thunder  0021900725 2020-01-31    OKC @ PHX     W
# 8808         Houston Rockets  0021900722 2020-01-31  HOU vs. DAL     W
# 8809  Portland Trail Blazers  0021900726 2020-01-31    POR @ LAL     W
# ...                      ...         ...        ...          ...   ...
# 5        Cleveland Cavaliers  0042200133 2023-04-21    CLE @ NYK     L
# 6             Denver Nuggets  0042200143 2023-04-21    DEN @ MIN     W
# 4             Boston Celtics  0042200113 2023-04-21    BOS @ ATL     L
# 1         Philadelphia 76ers  0042200124 2023-04-22    PHI @ BKN  None
# 0              Brooklyn Nets  0042200124 2023-04-22  BKN vs. PHI  None
#
#       PLUS_MINUS
# 8819       -13.0
# 8806        -8.0
# 8807         4.0
# 8808         7.0
# 8809         8.0
# ...          ...
# 5          -20.0
# 6            9.0
# 4           -8.0
# 1            8.0
# 0           -7.4
#
# [8820 rows x 6 columns]

# %%
games['avg_30_plus_minus'] = games.groupby('TEAM_NAME')['PLUS_MINUS'].transform(lambda x: x.rolling(30, closed='left').mean())

# %%
games
# Out:
#                    TEAM_NAME     GAME_ID  GAME_DATE      MATCHUP    WL  \
# 8819         Detroit Pistons  0021900720 2020-01-31  DET vs. TOR     L
# 8806      Los Angeles Lakers  0021900726 2020-01-31  LAL vs. POR     L
# 8807   Oklahoma City Thunder  0021900725 2020-01-31    OKC @ PHX     W
# 8808         Houston Rockets  0021900722 2020-01-31  HOU vs. DAL     W
# 8809  Portland Trail Blazers  0021900726 2020-01-31    POR @ LAL     W
# ...                      ...         ...        ...          ...   ...
# 5        Cleveland Cavaliers  0042200133 2023-04-21    CLE @ NYK     L
# 6             Denver Nuggets  0042200143 2023-04-21    DEN @ MIN     W
# 4             Boston Celtics  0042200113 2023-04-21    BOS @ ATL     L
# 1         Philadelphia 76ers  0042200124 2023-04-22    PHI @ BKN  None
# 0              Brooklyn Nets  0042200124 2023-04-22  BKN vs. PHI  None
#
#       PLUS_MINUS  avg_30_plus_minus
# 8819       -13.0                NaN
# 8806        -8.0                NaN
# 8807         4.0                NaN
# 8808         7.0                NaN
# 8809         8.0                NaN
# ...          ...                ...
# 5          -20.0           6.733333
# 6            9.0           3.466667
# 4           -8.0           7.966667
# 1            8.0           6.466667
# 0           -7.4          -2.566667
#
# [8820 rows x 7 columns]

# %%
games[games['TEAM_NAME']=='Toronto Raptors'].head(35)
# Out:
#             TEAM_NAME     GAME_ID  GAME_DATE      MATCHUP WL  PLUS_MINUS  \
# 8818  Toronto Raptors  0021900720 2020-01-31    TOR @ DET  W        13.0
# 8779  Toronto Raptors  0021900740 2020-02-02  TOR vs. CHI  W        27.0
# 8734  Toronto Raptors  0021900758 2020-02-05  TOR vs. IND  W         1.0
# 8712  Toronto Raptors  0021900772 2020-02-07    TOR @ IND  W         9.0
# 8692  Toronto Raptors  0021900781 2020-02-08  TOR vs. BKN  W         1.0
# 8669  Toronto Raptors  0021900796 2020-02-10  TOR vs. MIN  W        11.0
# 8626  Toronto Raptors  0021900809 2020-02-12    TOR @ BKN  L       -10.0
# 8589  Toronto Raptors  0021900829 2020-02-21  TOR vs. PHX  W        17.0
# 8556  Toronto Raptors  0021900843 2020-02-23  TOR vs. IND  W        46.0
# 8527  Toronto Raptors  0021900858 2020-02-25  TOR vs. MIL  L       -11.0
# 8484  Toronto Raptors  0021900879 2020-02-28  TOR vs. CHA  L        -3.0
# 8456  Toronto Raptors  0021900898 2020-03-01    TOR @ DEN  L       -15.0
# 8421  Toronto Raptors  0021900914 2020-03-03    TOR @ PHX  W         9.0
# 8401  Toronto Raptors  0021900929 2020-03-05    TOR @ GSW  W         8.0
# 8353  Toronto Raptors  0021900956 2020-03-08    TOR @ SAC  W         5.0
# 8339  Toronto Raptors  0021900959 2020-03-09    TOR @ UTA  W         9.0
# 8287  Toronto Raptors  0011900111 2020-07-24  TOR vs. HOU  W        11.0
# 8273  Toronto Raptors  0011900121 2020-07-26  TOR vs. POR  W         6.0
# 8247  Toronto Raptors  0011900129 2020-07-28    TOR @ PHX  L       -11.0
# 8225  Toronto Raptors  0021901243 2020-08-01  TOR vs. LAL  W        15.0
# 8199  Toronto Raptors  0021901250 2020-08-03    TOR @ MIA  W         4.0
# 8169  Toronto Raptors  0021901266 2020-08-05    TOR @ ORL  W        10.0
# 8155  Toronto Raptors  0021901279 2020-08-07  TOR vs. BOS  L       -22.0
# 8133  Toronto Raptors  0021901286 2020-08-09  TOR vs. MEM  W         9.0
# 8110  Toronto Raptors  0021901294 2020-08-10    TOR @ MIL  W         8.0
# 8095  Toronto Raptors  0021901305 2020-08-12    TOR @ PHI  W         4.0
# 8069  Toronto Raptors  0021901318 2020-08-14  TOR vs. DEN  W         8.0
# 8059  Toronto Raptors  0041900111 2020-08-17  TOR vs. BKN  W        24.0
# 8040  Toronto Raptors  0041900112 2020-08-19  TOR vs. BKN  W         5.0
# 8029  Toronto Raptors  0041900113 2020-08-21    TOR @ BKN  W        25.0
# 8015  Toronto Raptors  0041900114 2020-08-23    TOR @ BKN  W        28.0
# 7989  Toronto Raptors  0041900211 2020-08-30  TOR vs. BOS  L       -18.0
# 7979  Toronto Raptors  0041900212 2020-09-01  TOR vs. BOS  L        -3.0
# 7969  Toronto Raptors  0041900213 2020-09-03    TOR @ BOS  W         1.0
# 7963  Toronto Raptors  0041900214 2020-09-05    TOR @ BOS  W         7.0
#
#       avg_30_plus_minus
# 8818                NaN
# 8779                NaN
# 8734                NaN
# 8712                NaN
# 8692                NaN
# 8669                NaN
# 8626                NaN
# 8589                NaN
# 8556                NaN
# 8527                NaN
# 8484                NaN
# 8456                NaN
# 8421                NaN
# 8401                NaN
# 8353                NaN
# 8339                NaN
# 8287                NaN
# 8273                NaN
# 8247                NaN
# 8225                NaN
# 8199                NaN
# 8169                NaN
# 8155                NaN
# 8133                NaN
# 8110                NaN
# 8095                NaN
# 8069                NaN
# 8059                NaN
# 8040                NaN
# 8029                NaN
# 8015           7.100000
# 7989           7.600000
# 7979           6.100000
# 7969           5.966667
# 7963           5.700000

# %%
msk = games['MATCHUP'].str.contains('@')
games_away = games[msk]
games_home = games[~msk]

# %%
games_home.shape
# Out:
# (4410, 7)

# %%
games_away.shape
# Out:
# (4410, 7)

# %%
games_home
# Out:
#                    TEAM_NAME     GAME_ID  GAME_DATE      MATCHUP    WL  \
# 8819         Detroit Pistons  0021900720 2020-01-31  DET vs. TOR     L
# 8806      Los Angeles Lakers  0021900726 2020-01-31  LAL vs. POR     L
# 8808         Houston Rockets  0021900722 2020-01-31  HOU vs. DAL     W
# 8814         Milwaukee Bucks  0021900724 2020-01-31  MIL vs. DEN     L
# 8815            Phoenix Suns  0021900725 2020-01-31  PHX vs. OKC     L
# ...                      ...         ...        ...          ...   ...
# 9      Golden State Warriors  0042200163 2023-04-20  GSW vs. SAC     W
# 2            New York Knicks  0042200133 2023-04-21  NYK vs. CLE     W
# 3              Atlanta Hawks  0042200113 2023-04-21  ATL vs. BOS     W
# 7     Minnesota Timberwolves  0042200143 2023-04-21  MIN vs. DEN     L
# 0              Brooklyn Nets  0042200124 2023-04-22  BKN vs. PHI  None
#
#       PLUS_MINUS  avg_30_plus_minus
# 8819       -13.0                NaN
# 8806        -8.0                NaN
# 8808         7.0                NaN
# 8814       -12.0                NaN
# 8815        -4.0                NaN
# ...          ...                ...
# 9           17.0           4.066667
# 2           20.0           4.733333
# 3            8.0           1.033333
# 7           -9.0          -1.766667
# 0           -7.4          -2.566667
#
# [4410 rows x 7 columns]

# %%
games_away
# Out:
#                    TEAM_NAME     GAME_ID  GAME_DATE    MATCHUP    WL  \
# 8807   Oklahoma City Thunder  0021900725 2020-01-31  OKC @ PHX     W
# 8809  Portland Trail Blazers  0021900726 2020-01-31  POR @ LAL     W
# 8810          Denver Nuggets  0021900724 2020-01-31  DEN @ MIL     W
# 8811           Chicago Bulls  0021900721 2020-01-31  CHI @ BKN     L
# 8818         Toronto Raptors  0021900720 2020-01-31  TOR @ DET     W
# ...                      ...         ...        ...        ...   ...
# 8           Sacramento Kings  0042200163 2023-04-20  SAC @ GSW     L
# 5        Cleveland Cavaliers  0042200133 2023-04-21  CLE @ NYK     L
# 6             Denver Nuggets  0042200143 2023-04-21  DEN @ MIN     W
# 4             Boston Celtics  0042200113 2023-04-21  BOS @ ATL     L
# 1         Philadelphia 76ers  0042200124 2023-04-22  PHI @ BKN  None
#
#       PLUS_MINUS  avg_30_plus_minus
# 8807         4.0                NaN
# 8809         8.0                NaN
# 8810        12.0                NaN
# 8811       -15.0                NaN
# 8818        13.0                NaN
# ...          ...                ...
# 8          -17.0           2.800000
# 5          -20.0           6.733333
# 6            9.0           3.466667
# 4           -8.0           7.966667
# 1            8.0           6.466667
#
# [4410 rows x 7 columns]

# %%
games_merged = pd.merge(games_home, games_away, on='GAME_ID', suffixes=('_home', '_away'))
games_merged
# Out:
#               TEAM_NAME_home     GAME_ID GAME_DATE_home MATCHUP_home WL_home  \
# 0            Detroit Pistons  0021900720     2020-01-31  DET vs. TOR       L
# 1         Los Angeles Lakers  0021900726     2020-01-31  LAL vs. POR       L
# 2            Houston Rockets  0021900722     2020-01-31  HOU vs. DAL       W
# 3            Milwaukee Bucks  0021900724     2020-01-31  MIL vs. DEN       L
# 4               Phoenix Suns  0021900725     2020-01-31  PHX vs. OKC       L
# ...                      ...         ...            ...          ...     ...
# 4405   Golden State Warriors  0042200163     2023-04-20  GSW vs. SAC       W
# 4406         New York Knicks  0042200133     2023-04-21  NYK vs. CLE       W
# 4407           Atlanta Hawks  0042200113     2023-04-21  ATL vs. BOS       W
# 4408  Minnesota Timberwolves  0042200143     2023-04-21  MIN vs. DEN       L
# 4409           Brooklyn Nets  0042200124     2023-04-22  BKN vs. PHI    None
#
#       PLUS_MINUS_home  avg_30_plus_minus_home          TEAM_NAME_away  \
# 0               -13.0                     NaN         Toronto Raptors
# 1                -8.0                     NaN  Portland Trail Blazers
# 2                 7.0                     NaN        Dallas Mavericks
# 3               -12.0                     NaN          Denver Nuggets
# 4                -4.0                     NaN   Oklahoma City Thunder
# ...               ...                     ...                     ...
# 4405             17.0                4.066667        Sacramento Kings
# 4406             20.0                4.733333     Cleveland Cavaliers
# 4407              8.0                1.033333          Boston Celtics
# 4408             -9.0               -1.766667          Denver Nuggets
# 4409             -7.4               -2.566667      Philadelphia 76ers
#
#      GAME_DATE_away MATCHUP_away WL_away  PLUS_MINUS_away  \
# 0        2020-01-31    TOR @ DET       W             13.0
# 1        2020-01-31    POR @ LAL       W              8.0
# 2        2020-01-31    DAL @ HOU       L             -7.0
# 3        2020-01-31    DEN @ MIL       W             12.0
# 4        2020-01-31    OKC @ PHX       W              4.0
# ...             ...          ...     ...              ...
# 4405     2023-04-20    SAC @ GSW       L            -17.0
# 4406     2023-04-21    CLE @ NYK       L            -20.0
# 4407     2023-04-21    BOS @ ATL       L             -8.0
# 4408     2023-04-21    DEN @ MIN       W              9.0
# 4409     2023-04-22    PHI @ BKN    None              8.0
#
#       avg_30_plus_minus_away
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 4405                2.800000
# 4406                6.733333
# 4407                7.966667
# 4408                3.466667
# 4409                6.466667
#
# [4410 rows x 13 columns]

# %%
games_merged['avg_30_plus_minus_diff'] = games_merged['avg_30_plus_minus_home'] - games_merged['avg_30_plus_minus_away']

# %%
games_merged
# Out:
#               TEAM_NAME_home     GAME_ID GAME_DATE_home MATCHUP_home WL_home  \
# 0            Detroit Pistons  0021900720     2020-01-31  DET vs. TOR       L
# 1         Los Angeles Lakers  0021900726     2020-01-31  LAL vs. POR       L
# 2            Houston Rockets  0021900722     2020-01-31  HOU vs. DAL       W
# 3            Milwaukee Bucks  0021900724     2020-01-31  MIL vs. DEN       L
# 4               Phoenix Suns  0021900725     2020-01-31  PHX vs. OKC       L
# ...                      ...         ...            ...          ...     ...
# 4405   Golden State Warriors  0042200163     2023-04-20  GSW vs. SAC       W
# 4406         New York Knicks  0042200133     2023-04-21  NYK vs. CLE       W
# 4407           Atlanta Hawks  0042200113     2023-04-21  ATL vs. BOS       W
# 4408  Minnesota Timberwolves  0042200143     2023-04-21  MIN vs. DEN       L
# 4409           Brooklyn Nets  0042200124     2023-04-22  BKN vs. PHI    None
#
#       PLUS_MINUS_home  avg_30_plus_minus_home          TEAM_NAME_away  \
# 0               -13.0                     NaN         Toronto Raptors
# 1                -8.0                     NaN  Portland Trail Blazers
# 2                 7.0                     NaN        Dallas Mavericks
# 3               -12.0                     NaN          Denver Nuggets
# 4                -4.0                     NaN   Oklahoma City Thunder
# ...               ...                     ...                     ...
# 4405             17.0                4.066667        Sacramento Kings
# 4406             20.0                4.733333     Cleveland Cavaliers
# 4407              8.0                1.033333          Boston Celtics
# 4408             -9.0               -1.766667          Denver Nuggets
# 4409             -7.4               -2.566667      Philadelphia 76ers
#
#      GAME_DATE_away MATCHUP_away WL_away  PLUS_MINUS_away  \
# 0        2020-01-31    TOR @ DET       W             13.0
# 1        2020-01-31    POR @ LAL       W              8.0
# 2        2020-01-31    DAL @ HOU       L             -7.0
# 3        2020-01-31    DEN @ MIL       W             12.0
# 4        2020-01-31    OKC @ PHX       W              4.0
# ...             ...          ...     ...              ...
# 4405     2023-04-20    SAC @ GSW       L            -17.0
# 4406     2023-04-21    CLE @ NYK       L            -20.0
# 4407     2023-04-21    BOS @ ATL       L             -8.0
# 4408     2023-04-21    DEN @ MIN       W              9.0
# 4409     2023-04-22    PHI @ BKN    None              8.0
#
#       avg_30_plus_minus_away  avg_30_plus_minus_diff
# 0                        NaN                     NaN
# 1                        NaN                     NaN
# 2                        NaN                     NaN
# 3                        NaN                     NaN
# 4                        NaN                     NaN
# ...                      ...                     ...
# 4405                2.800000                1.266667
# 4406                6.733333               -2.000000
# 4407                7.966667               -6.933333
# 4408                3.466667               -5.233333
# 4409                6.466667               -9.033333
#
# [4410 rows x 14 columns]

# %%
games_merged[['WL_home', 'avg_30_plus_minus_diff']]
# Out:
#      WL_home  avg_30_plus_minus_diff
# 0          L                     NaN
# 1          L                     NaN
# 2          W                     NaN
# 3          L                     NaN
# 4          L                     NaN
# ...      ...                     ...
# 4405       W                1.266667
# 4406       W               -2.000000
# 4407       W               -6.933333
# 4408       L               -5.233333
# 4409    None               -9.033333
#
# [4410 rows x 2 columns]

# %%
games_model = games_merged[['WL_home', 'avg_30_plus_minus_diff']].dropna()
games_model
# Out:
#      WL_home  avg_30_plus_minus_diff
# 398        W                1.933333
# 399        L               -6.233333
# 401        L               -5.366667
# 402        W                2.466667
# 403        L               -5.600000
# ...      ...                     ...
# 4404       L               -3.233333
# 4405       W                1.266667
# 4406       W               -2.000000
# 4407       W               -6.933333
# 4408       L               -5.233333
#
# [3891 rows x 2 columns]

# %%
games_model['WL_home'] = games_model['WL_home'].map({'W': 1, 'L': 0})

# %%
games_model
# Out:
#       WL_home  avg_30_plus_minus_diff
# 398         1                1.933333
# 399         0               -6.233333
# 401         0               -5.366667
# 402         1                2.466667
# 403         0               -5.600000
# ...       ...                     ...
# 4404        0               -3.233333
# 4405        1                1.266667
# 4406        1               -2.000000
# 4407        1               -6.933333
# 4408        0               -5.233333
#
# [3891 rows x 2 columns]

# %% [markdown]
# # Build the predictive model, hyperparameter tuning, evaluation

# %%
from sklearn.model_selection import train_test_split

# %%
df_train, df_test = train_test_split(games_model, stratify=games_model['WL_home'], test_size=0.2, random_state=7)

# %%
df_train.shape
# Out:
# (3112, 2)

# %%
df_test.shape
# Out:
# (779, 2)

# %%
target = 'WL_home'
X_train = df_train.drop(columns=target)
y_train = df_train[target]

X_test = df_test.drop(columns=target)
y_test= df_test[target]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import RandomizedSearchCV



clf = RandomForestClassifier(random_state=7)

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

accuracy_score(y_test, y_pred)
# Out:
# 0.5661103979460848

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.utils.fixes import loguniform

# %%
hyp_params = {'n_estimators': [10, 50, 100, 150, 200, 250],
              'criterion': ['gini', 'entropy'], # RF, Gini and Entropy are the metrics
              'max_depth': [3, 5, 7, 9, 11, 13], # Max-depth of the DT
              'min_samples_split': [2, 4, 6, 8],
              'min_samples_leaf': [1, 2, 3, 4, 5]}

# %%
random_hyp = RandomizedSearchCV(estimator=clf, 
                                param_distributions=hyp_params, 
                                n_iter=20, 
                                cv=7,
                                scoring='accuracy',
                                random_state=7)

# %%
random_hyp.fit(X_train, y_train)

random_hyp.best_params_

model_hyp = random_hyp.best_estimator_

y_pred_hyp = model_hyp.predict(X_test)

accuracy_score(y_test, y_pred_hyp)
# Out:
# 0.6341463414634146

# %% [markdown]
# # Deploy the model with FastAPI

# %%
from joblib import dump, load
dump(model_hyp, 'model_nba.joblib') 
model_saved = load('model_nba.joblib') 

accuracy_score(y_test, model_saved.predict(X_test))
# Out:
# 0.6341463414634146

# %%
# Similar Above Code
# copied all from above
from nba_api.stats.endpoints import leaguegamefinder
gamefinder = leaguegamefinder.LeagueGameFinder(date_from_nullable='01/31/2020', league_id_nullable='00')
games = gamefinder.get_data_frames()[0]

games = games[['TEAM_NAME', 'GAME_ID', 'GAME_DATE', 'MATCHUP', 'WL', 'PLUS_MINUS']]

import pandas as pd

games['GAME_DATE'] = pd.to_datetime(games['GAME_DATE'])

games = games.sort_values('GAME_DATE')

games['avg_30_plus_minus'] = games.groupby('TEAM_NAME')['PLUS_MINUS'].transform(lambda x: x.rolling(30, closed='left').mean())

msk = games['MATCHUP'].str.contains('@')
games_away = games[msk]
games_home = games[~msk]

games_merged = pd.merge(games_home, games_away, on='GAME_ID', suffixes=('_home', '_away'))

games_merged['avg_30_plus_minus_diff'] = games_merged['avg_30_plus_minus_home'] - games_merged['avg_30_plus_minus_away']

# %%
team_home='Toronto Raptors'
team_away='Boston Celtics'

import numpy as np
gamefinder = leaguegamefinder.LeagueGameFinder(date_from_nullable='01/01/2021',
                                           league_id_nullable='00')
games = gamefinder.get_data_frames()[0]
games = games[['TEAM_NAME', 'GAME_ID', 'GAME_DATE', 'MATCHUP', 'WL', 'PLUS_MINUS']]
games['GAME_DATE'] = pd.to_datetime(games['GAME_DATE'])

msk_home = (games['TEAM_NAME'] == team_home)
games_30_home = games[msk_home].sort_values('GAME_DATE').tail(30)
home_plus_minus = games_30_home['PLUS_MINUS'].mean()

msk_away = (games['TEAM_NAME'] == team_away)
games_30_away = games[msk_away].sort_values('GAME_DATE').tail(30)
away_plus_minus = games_30_away['PLUS_MINUS'].mean()

games_diff=home_plus_minus - away_plus_minus
games_diff = np.array([games_diff])
predict_home_win=model_saved.predict(games_diff.reshape(1, -1))[0]
predict_winning_probability=model_saved.predict_proba(games_diff.reshape(1, -1))[0][1]


# predict_home_win=model_saved.predict(np.array([games_diff]))[0]
# predict_winning_probability=model_saved.predict_proba(np.array([games_diff]))[0][1]
# Out:
# C:\Users\91996\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\91996\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
def predict_games(team_home, team_away):
    gamefinder = leaguegamefinder.LeagueGameFinder(
        date_from_nullable='01/01/2021',
        league_id_nullable='00')
    games = gamefinder.get_data_frames()[0]
    games = games[
        ['TEAM_NAME', 'GAME_ID', 'GAME_DATE', 'MATCHUP', 'WL', 'PLUS_MINUS']]
    games['GAME_DATE'] = pd.to_datetime(games['GAME_DATE'])

    msk_home = (games['TEAM_NAME'] == team_home)
    games_30_home = games[msk_home].sort_values('GAME_DATE').tail(30)
    home_plus_minus = games_30_home['PLUS_MINUS'].mean()

    msk_away = (games['TEAM_NAME'] == team_away)
    games_30_away = games[msk_away].sort_values('GAME_DATE').tail(30)
    away_plus_minus = games_30_away['PLUS_MINUS'].mean()

    games_diff = home_plus_minus - away_plus_minus
    games_diff = np.array([games_diff])
    predict_home_win=model_saved.predict(games_diff.reshape(1, -1))[0]
    predict_winning_probability=model_saved.predict_proba(games_diff.reshape(1, -1))[0][1]


#     predict_home_win = model_saved.predict(np.array([games_diff]))[0]
#     predict_winning_probability = model_saved.predict_proba(np.array([games_diff]))[0][1]
    return predict_home_win, predict_winning_probability

# %%
predict_games('Boston Celtics','Toronto Raptors')
# Out:
# C:\Users\91996\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\91996\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# (1, 0.6991054176515216)
